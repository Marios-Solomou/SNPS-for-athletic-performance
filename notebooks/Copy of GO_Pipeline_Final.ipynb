# %%
# !pip install goatools
# Out:
# Collecting goatools
#   Downloading goatools-1.4.12-py3-none-any.whl.metadata (14 kB)
# Collecting docopt (from goatools)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ftpretty (from goatools)
#   Downloading ftpretty-0.4.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from goatools) (1.26.4)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (from goatools) (3.1.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from goatools) (2.2.2)
# Requirement already satisfied: pydot in /usr/local/lib/python3.11/dist-packages (from goatools) (3.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from goatools) (2.32.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from goatools) (13.9.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from goatools) (1.13.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from goatools) (75.1.0)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (from goatools) (0.14.4)
# Collecting xlsxwriter (from goatools)
#   Downloading XlsxWriter-3.2.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from ftpretty->goatools) (2.8.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl->goatools) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->goatools) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->goatools) (2025.1)
# Requirement already satisfied: pyparsing>=3.0.9 in /usr/local/lib/python3.11/dist-packages (from pydot->goatools) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->goatools) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->goatools) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->goatools) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->goatools) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->goatools) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->goatools) (2.18.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels->goatools) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels->goatools) (24.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->goatools) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->ftpretty->goatools) (1.17.0)
# Downloading goatools-1.4.12-py3-none-any.whl (15.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 58.6 MB/s eta 0:00:00
# Downloading ftpretty-0.4.0-py2.py3-none-any.whl (8.2 kB)
# Downloading XlsxWriter-3.2.2-py3-none-any.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.1/165.1 kB 11.1 MB/s eta 0:00:00
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=75f533000f05a3ad261c19f979febe808747d97c51917e7d439c890d3f1ad0e8
#   Stored in directory: /root/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built docopt
# Installing collected packages: docopt, xlsxwriter, ftpretty, goatools
# Successfully installed docopt-0.6.2 ftpretty-0.4.0 goatools-1.4.12 xlsxwriter-3.2.2

# %%
import os
import pickle
from goatools.base import download_go_basic_obo, download_ncbi_associations
from goatools.obo_parser import GODag
from goatools.anno.genetogo_reader import Gene2GoReader
from goatools.cli.ncbi_gene_results_to_python import ncbi_tsv_to_py
from goatools.goea.go_enrichment_ns import GOEnrichmentStudyNS
from goatools.cli.ncbi_gene_results_to_python import ncbi_tsv_to_py

def download_data():
    #Downloads necessary data files
    # !wget http://geneontology.org/ontology/go-basic.obo -O go-basic.obo
    # !wget https://ftp.ncbi.nlm.nih.gov/gene/DATA/gene2go.gz -O gene2go.gz
    # !gunzip gene2go.gz
    obo_fname = 'go-basic.obo'
    fin_gene2go = 'gene2go'
    return obo_fname, fin_gene2go

def create_background_gene_set(NCBI_file='protein coding human.txt'):
    output_py = 'genes_ncbi_9606_proteincoding.py'
    ncbi_tsv_to_py(NCBI_file, output_py)
    from genes_ncbi_9606_proteincoding import GENEID2NT
    background = []
    for gene in iter(sorted(GENEID2NT.values())):
      geneobj = sorted(gene._asdict().items())
      background.append(geneobj[2][1])

    print(len((set(background))))
    with open('background.pkl', 'wb') as f:
        pickle.dump(background, f)
    return background

def load_data(obo_fname, fin_gene2go, background_file='background.pkl'):
    #Loads ontologies, associations, and background gene set
    obodag = GODag(obo_fname)
    objanno = Gene2GoReader(fin_gene2go, taxids=[9606])
    ns2assoc = objanno.get_ns2assc()
    for nspc, id2gos in ns2assoc.items():
      print("{NS} {N:,} annotated human genes".format(NS=nspc, N=len(id2gos)))

    with open(background_file, 'rb') as f:
        background = pickle.load(f)
    background = list(map(int, background))

    return obodag, ns2assoc, background

def initialize_goea(background, ns2assoc, obodag):
    #Initializes a GOEA object
    goeaobj = GOEnrichmentStudyNS(
        background,
        ns2assoc,
        obodag,
        propagate_counts=False,
        alpha=0.05,
        methods=['fdr_bh']
    )
    return goeaobj

def load_study_genes(study_genes_file='entrez_lists.pkl'):
    #Loads study genes from a file
    with open(study_genes_file, 'rb') as f:
        dics = pickle.load(f)
    return dics

def run_goea(goeaobj, study_genes):
    #Runs GOEA for each phenotype and exports results to Excel
    for phenotype, gene_list in study_genes.items():
        geneids_study = list(map(int, gene_list))
        goea_results_all = goeaobj.run_study(geneids_study)
        goea_results_sig = [r for r in goea_results_all if r.p_fdr_bh < 0.05]
        goeaobj.wr_xlsx(f"{phenotype}.xlsx", goea_results_sig)

#Pipeline execution
obo_fname, fin_gene2go = download_data()
create_background_gene_set()
obodag, ns2assoc, background = load_data(obo_fname, fin_gene2go)
goeaobj = initialize_goea(background, ns2assoc, obodag)
study_genes = load_study_genes()
run_goea(goeaobj, study_genes)
# Out:
# --2025-03-06 16:44:38--  http://geneontology.org/ontology/go-basic.obo
# Resolving geneontology.org (geneontology.org)... 34.233.67.155
# Connecting to geneontology.org (geneontology.org)|34.233.67.155|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://geneontology.org/ontology/go-basic.obo [following]
# --2025-03-06 16:44:38--  https://geneontology.org/ontology/go-basic.obo
# Connecting to geneontology.org (geneontology.org)|34.233.67.155|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: http://purl.obolibrary.org/obo/go/go-basic.obo [following]
# --2025-03-06 16:44:38--  http://purl.obolibrary.org/obo/go/go-basic.obo
# Resolving purl.obolibrary.org (purl.obolibrary.org)... 172.64.150.197, 104.18.37.59, 2606:4700:4400::6812:253b, ...
# Connecting to purl.obolibrary.org (purl.obolibrary.org)|172.64.150.197|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://current.geneontology.org/ontology/go-basic.obo [following]
# --2025-03-06 16:44:38--  https://current.geneontology.org/ontology/go-basic.obo
# Resolving current.geneontology.org (current.geneontology.org)... 3.166.181.122, 3.166.181.20, 3.166.181.7, ...
# Connecting to current.geneontology.org (current.geneontology.org)|3.166.181.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31280392 (30M) [text/obo]
# Saving to: ‘go-basic.obo’
#
# go-basic.obo        100%[===================>]  29.83M  95.9MB/s    in 0.3s
#
# 2025-03-06 16:44:39 (95.9 MB/s) - ‘go-basic.obo’ saved [31280392/31280392]
#
# --2025-03-06 16:44:39--  https://ftp.ncbi.nlm.nih.gov/gene/DATA/gene2go.gz
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.31, 130.14.250.10, 130.14.250.11, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1170251482 (1.1G) [application/x-gzip]
# Saving to: ‘gene2go.gz’
#
# gene2go.gz          100%[===================>]   1.09G   126MB/s    in 12s
#
# 2025-03-06 16:44:51 (91.4 MB/s) - ‘gene2go.gz’ saved [1170251482/1170251482]
#
# gzip: gene2go already exists; do you wish to overwrite (y or n)? n
# 	not overwritten
#       20,616 lines READ:  protein coding human.txt
#       20,596 geneids WROTE: genes_ncbi_9606_proteincoding.py
# 20596
# go-basic.obo: fmt(1.2) rel(2025-02-06) 43,597 Terms
# HMS:0:02:32.562717 362,439 annotations, 20,832 genes, 18,691 GOs, 1 taxids READ: gene2go
# BP 18,758 annotated human genes
# CC 19,880 annotated human genes
# MF 18,592 annotated human genes
#
# Load BP Ontology Enrichment Analysis ...
#  83% 17,079 of 20,596 population items found in association
#
# Load CC Ontology Enrichment Analysis ...
#  89% 18,232 of 20,596 population items found in association
#
# Load MF Ontology Enrichment Analysis ...
#  87% 17,822 of 20,596 population items found in association
#
# Runing BP Ontology Analysis: current study set of 24 IDs.
# 100%     24 of     24 study items found in association
# 100%     24 of     24 study items found in population(20596)
# Calculating 12,080 uncorrected p-values using fisher_scipy_stats
#   12,080 terms are associated with 17,079 of 20,596 population items
#      552 terms are associated with     24 of     24 study items
#   METHOD fdr_bh:
#       22 GO terms found significant (< 0.05=alpha) ( 22 enriched +   0 purified): statsmodels fdr_bh
#       16 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Runing CC Ontology Analysis: current study set of 24 IDs.
# 100%     24 of     24 study items found in association
# 100%     24 of     24 study items found in population(20596)
# Calculating 1,822 uncorrected p-values using fisher_scipy_stats
#    1,822 terms are associated with 18,232 of 20,596 population items
#       97 terms are associated with     24 of     24 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Runing MF Ontology Analysis: current study set of 24 IDs.
# 100%     24 of     24 study items found in association
# 100%     24 of     24 study items found in population(20596)
# Calculating 4,640 uncorrected p-values using fisher_scipy_stats
#    4,640 terms are associated with 17,822 of 20,596 population items
#      197 terms are associated with     24 of     24 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#      22 items WROTE: endurance.xlsx
#
# Runing BP Ontology Analysis: current study set of 23 IDs.
# 100%     23 of     23 study items found in association
# 100%     23 of     23 study items found in population(20596)
# Calculating 12,080 uncorrected p-values using fisher_scipy_stats
#   12,080 terms are associated with 17,079 of 20,596 population items
#      255 terms are associated with     23 of     23 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.05=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#        2 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Runing CC Ontology Analysis: current study set of 23 IDs.
# 100%     23 of     23 study items found in association
# 100%     23 of     23 study items found in population(20596)
# Calculating 1,822 uncorrected p-values using fisher_scipy_stats
#    1,822 terms are associated with 18,232 of 20,596 population items
#       66 terms are associated with     23 of     23 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Runing MF Ontology Analysis: current study set of 23 IDs.
#  96%     22 of     23 study items found in association
# 100%     23 of     23 study items found in population(20596)
# Calculating 4,640 uncorrected p-values using fisher_scipy_stats
#    4,640 terms are associated with 17,822 of 20,596 population items
#       90 terms are associated with     22 of     23 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#       1 items WROTE: power.xlsx
#
# Runing BP Ontology Analysis: current study set of 27 IDs.
#  89%     24 of     27 study items found in association
# 100%     27 of     27 study items found in population(20596)
# Calculating 12,080 uncorrected p-values using fisher_scipy_stats
#   12,080 terms are associated with 17,079 of 20,596 population items
#      209 terms are associated with     24 of     27 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Runing CC Ontology Analysis: current study set of 27 IDs.
#  93%     25 of     27 study items found in association
# 100%     27 of     27 study items found in population(20596)
# Calculating 1,822 uncorrected p-values using fisher_scipy_stats
#    1,822 terms are associated with 18,232 of 20,596 population items
#       85 terms are associated with     25 of     27 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Runing MF Ontology Analysis: current study set of 27 IDs.
#  96%     26 of     27 study items found in association
# 100%     27 of     27 study items found in population(20596)
# Calculating 4,640 uncorrected p-values using fisher_scipy_stats
#    4,640 terms are associated with 17,822 of 20,596 population items
#       87 terms are associated with     26 of     27 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# **WARNING: NOT WRITING strength.xlsx; NO ENRICHMENT RESULTS
#
# Runing BP Ontology Analysis: current study set of 6 IDs.
# 100%      6 of      6 study items found in association
# 100%      6 of      6 study items found in population(20596)
# Calculating 12,080 uncorrected p-values using fisher_scipy_stats
#   12,080 terms are associated with 17,079 of 20,596 population items
#      204 terms are associated with      6 of      6 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Runing CC Ontology Analysis: current study set of 6 IDs.
# 100%      6 of      6 study items found in association
# 100%      6 of      6 study items found in population(20596)
# Calculating 1,822 uncorrected p-values using fisher_scipy_stats
#    1,822 terms are associated with 18,232 of 20,596 population items
#       32 terms are associated with      6 of      6 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#
# Runing MF Ontology Analysis: current study set of 6 IDs.
# 100%      6 of      6 study items found in association
# 100%      6 of      6 study items found in population(20596)
# Calculating 4,640 uncorrected p-values using fisher_scipy_stats
#    4,640 terms are associated with 17,822 of 20,596 population items
#       62 terms are associated with      6 of      6 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.05=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# **WARNING: NOT WRITING shared.xlsx; NO ENRICHMENT RESULTS

# %%
import pandas as pd
e = pd.read_excel('E.xlsx')

# %%
e
# Out:
#             GO  NS enrichment  \
# 0   GO:0120162  BP          e
# 1   GO:0043536  BP          e
# 2   GO:0045766  BP          e
# 3   GO:1902894  BP          e
# 4   GO:0009409  BP          e
# 5   GO:0001569  BP          e
# 6   GO:0043524  BP          e
# 7   GO:0010629  BP          e
# 8   GO:0097746  BP          e
# 9   GO:0001666  BP          e
# 10  GO:0010883  BP          e
# 11  GO:0042311  BP          e
# 12  GO:0001938  BP          e
# 13  GO:0045722  BP          e
# 14  GO:0001659  BP          e
# 15  GO:0002025  BP          e
# 16  GO:0001678  BP          e
# 17  GO:0048593  BP          e
# 18  GO:0071460  BP          e
# 19  GO:0090400  BP          e
# 20  GO:0031649  BP          e
# 21  GO:0090335  BP          e
# 22  GO:0050873  BP          e
# 23  GO:0016239  BP          e
# 24  GO:0051402  BP          e
# 25  GO:0045944  BP          e
# 26  GO:1901532  BP          e
# 27  GO:0000303  BP          e
# 28  GO:0030225  BP          e
# 29  GO:0036324  BP          e
# 30  GO:0046321  BP          e
# 31  GO:0001974  BP          e
# 32  GO:0071456  BP          e
# 33  GO:0061042  BP          e
# 34  GO:0001542  BP          e
# 35  GO:0001525  BP          e
# 36  GO:0010628  BP          e
# 37  GO:0003007  BP          e
# 38  GO:0050927  BP          e
# 39  GO:0002070  BP          e
# 40  GO:0097009  BP          e
#
#                                                  name ratio_in_study  \
# 0   positive regulation of cold-induced thermogenesis           7/36
# 1   positive regulation of blood vessel endothelia...           5/36
# 2                 positive regulation of angiogenesis           6/36
# 3          negative regulation of miRNA transcription           4/36
# 4                                    response to cold           4/36
# 5    branching involved in blood vessel morphogenesis           4/36
# 6     negative regulation of neuron apoptotic process           6/36
# 7              negative regulation of gene expression           7/36
# 8                   blood vessel diameter maintenance           4/36
# 9                                 response to hypoxia           6/36
# 10                        regulation of lipid storage           3/36
# 11                                       vasodilation           4/36
# 12  positive regulation of endothelial cell prolif...           4/36
# 13             positive regulation of gluconeogenesis           3/36
# 14                            temperature homeostasis           3/36
# 15  norepinephrine-epinephrine-mediated vasodilati...           2/36
# 16                  intracellular glucose homeostasis           3/36
# 17                      camera-type eye morphogenesis           3/36
# 18          cellular response to cell-matrix adhesion           2/36
# 19                stress-induced premature senescence           2/36
# 20                                    heat generation           2/36
# 21       regulation of brown fat cell differentiation           2/36
# 22                     brown fat cell differentiation           3/36
# 23              positive regulation of macroautophagy           3/36
# 24                           neuron apoptotic process           4/36
# 25  positive regulation of transcription by RNA po...          10/36
# 26  regulation of hematopoietic progenitor cell di...           2/36
# 27                             response to superoxide           2/36
# 28                         macrophage differentiation           3/36
# 29  vascular endothelial growth factor receptor-2 ...           2/36
# 30        positive regulation of fatty acid oxidation           2/36
# 31                            blood vessel remodeling           3/36
# 32                       cellular response to hypoxia           4/36
# 33                             vascular wound healing           2/36
# 34                    ovulation from ovarian follicle           2/36
# 35                                       angiogenesis           5/36
# 36             positive regulation of gene expression           6/36
# 37                                heart morphogenesis           3/36
# 38         positive regulation of positive chemotaxis           2/36
# 39                         epithelial cell maturation           2/36
# 40                                 energy homeostasis           3/36
#
#    ratio_in_pop  p_uncorrected  depth  study_count  p_fdr_bh  \
# 0     101/20596   4.102782e-10      6            7  0.000005
# 1      38/20596   5.881255e-09      8            5  0.000036
# 2     137/20596   1.282670e-07      7            6  0.000407
# 3      27/20596   1.340329e-07     11            4  0.000407
# 4      30/20596   2.085181e-07      4            4  0.000481
# 5      31/20596   2.391121e-07      7            4  0.000481
# 6     156/20596   2.767870e-07      7            6  0.000481
# 7     266/20596   3.357390e-07      8            7  0.000510
# 8      36/20596   4.448623e-07      6            4  0.000601
# 9     173/20596   5.088891e-07      5            6  0.000619
# 10     10/20596   5.835658e-07      4            3  0.000645
# 11     48/20596   1.447743e-06      7            4  0.001467
# 12     69/20596   6.266440e-06      7            4  0.005544
# 13     21/20596   6.382900e-06      9            3  0.005544
# 14     23/20596   8.478933e-06      3            3  0.006765
# 15      3/20596   8.901616e-06      8            2  0.006765
# 16     26/20596   1.240311e-05      5            3  0.008871
# 17     27/20596   1.393674e-05      6            3  0.009414
# 18      4/20596   1.778364e-05      3            2  0.009829
# 19      4/20596   1.778364e-05      3            2  0.009829
# 20      4/20596   1.778364e-05      4            2  0.009829
# 21      4/20596   1.778364e-05      6            2  0.009829
# 22     32/20596   2.349138e-05      5            3  0.011901
# 23     32/20596   2.349138e-05      8            3  0.011901
# 24     98/20596   2.525717e-05      5            4  0.012009
# 25   1191/20596   2.567881e-05     11           10  0.012009
# 26      5/20596   2.960678e-05      5            2  0.012857
# 27      5/20596   2.960678e-05      6            2  0.012857
# 28     36/20596   3.365415e-05      6            3  0.014110
# 29      6/20596   4.436131e-05      9            2  0.017400
# 30      6/20596   4.436131e-05      9            2  0.017400
# 31     42/20596   5.372214e-05      3            3  0.020413
# 32    127/20596   6.970308e-05      6            4  0.025682
# 33      9/20596   1.061162e-04      5            2  0.036865
# 34      9/20596   1.061162e-04      4            2  0.036865
# 35    282/20596   1.236734e-04      3            5  0.041771
# 36    462/20596   1.356834e-04      8            6  0.044588
# 37     59/20596   1.490575e-04      4            3  0.047694
# 38     11/20596   1.617655e-04      7            2  0.048821
# 39     11/20596   1.617655e-04      5            2  0.048821
# 40     61/20596   1.646229e-04      3            3  0.048821
#
#                                           study_items
# 0           154, 155, 7253, 7351, 7422, 10891, 133522
# 1                       3091, 3791, 4846, 7422, 23411
# 2                  358, 3091, 3791, 4846, 7422, 23411
# 3                              3091, 4776, 5465, 7422
# 4                                154, 155, 7351, 7352
# 5                              3791, 4776, 5534, 7422
# 6                3091, 3791, 4776, 7351, 10891, 23411
# 7            639, 1026, 1636, 3091, 3791, 7422, 23411
# 8                                154, 186, 1636, 4846
# 9                  3091, 5465, 7019, 7351, 7352, 7422
# 10                                 5465, 23411, 79068
# 11                               186, 624, 4846, 7422
# 12                            3091, 3791, 7422, 23411
# 13                                 5465, 10891, 23411
# 14                                 7226, 10891, 79068
# 15                                           154, 155
# 16                                 3091, 10891, 23411
# 17                                    358, 3091, 7422
# 18                                         1026, 2950
# 19                                        1026, 23411
# 20                                           154, 155
# 21                                       23411, 79068
# 22                                    154, 155, 10891
# 23                                  3091, 3791, 23411
# 24                             186, 3091, 4776, 10891
# 25  154, 2553, 3091, 4776, 5465, 5534, 7422, 10891...
# 26                                         3791, 7422
# 27                                         7351, 7352
# 28                                  7351, 7422, 23411
# 29                                         3791, 7422
# 30                                        5465, 10891
# 31                                    186, 1636, 4846
# 32                             358, 3091, 7422, 23411
# 33                                         3791, 7422
# 34                                        4846, 23411
# 35                      3091, 3791, 4846, 7422, 23411
# 36                 639, 3077, 3091, 4846, 7422, 10891
# 37                                   1289, 4607, 7422
# 38                                         3791, 7422
# 39                                         3791, 7422
# 40                               10891, 23411, 133522
